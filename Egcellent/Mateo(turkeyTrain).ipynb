# %% [markdown]
# # The Eggcellent Detector EDA

# %% [markdown]
# This part of the notebook imports the basic packages

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import operator 
import re
import sys
import csv

import seaborn as sns
from matplotlib import pyplot as plt

# %%
Test_DF = pd.read_csv("/content/drive/MyDrive/The Eggcellent Predictor /Data/TURKEYtrain.csv")

# %%
Test_DF.head(10)
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
# 9  National Average         52  Rice - Retail     5     KG      7  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202
# 8  6.6019
# 9  6.6503

# %%
product_name = Test_DF["ProductName"]
product_name.head()
# Out:
# 0    Rice - Retail
# 1    Rice - Retail
# 2    Rice - Retail
# 3    Rice - Retail
# 4    Rice - Retail
# Name: ProductName, dtype: object

# %%
egg_rows = Test_DF[Test_DF["ProductName"].str.contains("Eggs - Retail")]

# %%
egg_rows.shape
# Out:
# (174, 8)

# %%
egg_rows.to_csv("EggRowsTrain.csv")

# %%
New_DF = pd.read_csv("/content/EggRowsTrain.csv")
New_DF.head(10)
# Out:
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0         244  National Average         92  Eggs - Retail    33   Unit      5
# 1         245  National Average         92  Eggs - Retail    33   Unit      6
# 2         246  National Average         92  Eggs - Retail    33   Unit     11
# 3         247  National Average         92  Eggs - Retail    33   Unit     12
# 4         248  National Average         92  Eggs - Retail    33   Unit      1
# 5         249  National Average         92  Eggs - Retail    33   Unit      2
# 6         250  National Average         92  Eggs - Retail    33   Unit      3
# 7         251  National Average         92  Eggs - Retail    33   Unit      5
# 8         252  National Average         92  Eggs - Retail    33   Unit      6
# 9         253  National Average         92  Eggs - Retail    33   Unit      7
#
#    Year   Price
# 0  2013  0.2539
# 1  2013  0.2677
# 2  2013  0.3556
# 3  2013  0.3635
# 4  2014  0.3749
# ...

# %%
place_name = New_DF["Place"]
place_name.head()
# Out:
# 0    National Average
# 1    National Average
# 2    National Average
# 3    National Average
# 4    National Average
# Name: Place, dtype: object

# %%
national_average = New_DF[New_DF["Place"].str.contains("National Average")]
national_average.shape
# Out:
# (66, 9)

# %%
national_average.to_csv("NatAverageTurkey.csv")

# %%
ankara_set = New_DF[New_DF["Place"].str.contains("Ankara")]
ankara_set.shape
# Out:
# (36, 9)

# %%
istanbul_set = New_DF[New_DF["Place"].str.contains("Istanbul")]
istanbul_set.shape
# Out:
# (36, 9)

# %%
izmir_set = New_DF[New_DF["Place"].str.contains("Izmir")]
izmir_set.shape
# Out:
# (36, 9)

# %%
istanbul_set.to_csv("IstanbulTurkey.csv")
izmir_set.to_csv("IzmirTurkey.csv")
ankara_set.to_csv("AnkaraTurkey.csv")

# %%
x = []
y = []
  
with open('EggRowsTrain.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        x.append(row[0])
        y.append(int(row[1]))
  
plt.plot(x, y, color = 'g', linestyle = 'dashed',
         marker = 'o',label = "Price")
  
plt.xticks(rotation = 25)
plt.xlabel('Dates')
plt.ylabel('Egg Price per Dozen')
plt.title('Egg Prices in Turkey', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-26be8e119b3a> in <cell line: 4>()
#       6     for row in lines:
#       7         x.append(row[0])
# ----> 8         y.append(int(row[1]))
#       9
#      10 plt.plot(x, y, color = 'g', linestyle = 'dashed',
#
# ValueError: invalid literal for int() with base 10: 'Place'
